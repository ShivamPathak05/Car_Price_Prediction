# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('car data.csv')

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df=df.drop(labels='Car_Name',axis=1)

# %%
df=df.drop(labels='Owner',axis=1)

# %% [markdown]
# #Data Split X & Y

# %%
X=df.drop(labels='Selling_Price',axis=1)

# %%
X
# Out:
#      Year  Present_Price  Kms_Driven Fuel_Type Seller_Type Transmission
# 0    2014           5.59       27000    Petrol      Dealer       Manual
# 1    2013           9.54       43000    Diesel      Dealer       Manual
# 2    2017           9.85        6900    Petrol      Dealer       Manual
# 3    2011           4.15        5200    Petrol      Dealer       Manual
# 4    2014           6.87       42450    Diesel      Dealer       Manual
# ..    ...            ...         ...       ...         ...          ...
# 296  2016          11.60       33988    Diesel      Dealer       Manual
# 297  2015           5.90       60000    Petrol      Dealer       Manual
# 298  2009          11.00       87934    Petrol      Dealer       Manual
# 299  2017          12.50        9000    Diesel      Dealer       Manual
# 300  2016           5.90        5464    Petrol      Dealer       Manual
#
# [301 rows x 6 columns]

# %%
y=df['Selling_Price']
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %% [markdown]
# #DATA SPLITTING

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=42)

# %%
X_train.head()
# Out:
#      Year  Present_Price  Kms_Driven Fuel_Type Seller_Type Transmission
# 282  2014          14.00       63000    Diesel      Dealer       Manual
# 163  2010           0.95       27000    Petrol  Individual       Manual
# 42   2008           7.15       58000    Petrol      Dealer       Manual
# 17   2016          10.79       43000    Diesel      Dealer       Manual
# 266  2014           7.00       35000    Petrol      Dealer       Manual

# %%
y_train.head()
# Out:
# 282    8.25
# 163    0.45
# 42     1.95
# 17     7.75
# 266    3.65
# Name: Selling_Price, dtype: float64

# %%
price=(y_pred*100000).astype(int)

# %% [markdown]
# #MAKING PIPE LINES OF THE DATA

# %%
trf1 = ColumnTransformer(
    transformers=[('one hot encoding', OneHotEncoder(sparse=False, handle_unknown='ignore'), [3, 4, 5])],
    remainder='passthrough'
)

# %%
trf2=LinearRegression()

# %%
pipe=make_pipeline(trf1,trf2)

# %%
pipe.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('one hot encoding',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   [3, 4, 5])])),
#                 ('linearregression', LinearRegression())])

# %% [markdown]
# #CHECKING THE ACCURACY OF THE MODEL

# %%
y_pred=pipe.predict(X_train)
y_pre=pipe.predict(X_test)

# %%
from sklearn. metrics import r2_score
r1=r2_score(y_train,y_pred)
r2=r2_score(y_test,y_pre)
print("ACCURACY OF THE TRAINING DATA IS:- ",r1)
print("ACCURACY OF THE TEST DATA IS:- ",r2)
# Out:
# ACCURACY OF THE TRAINING DATA IS:-  0.8840754497180532
# ACCURACY OF THE TEST DATA IS:-  0.8267881775397163

# %% [markdown]
# #LOAD IN PICKEL

# %%
import pickle

# %%
pickle.dump(pipe,open('car_price_model.pkl','wb'))

# %% [markdown]
# #OPEN IN PICKEL

# %%
vlu=pickle.load(open('car_price_model.pkl','rb'))

# %%
tst_inp=np.array([2014,1345678,5000,'Petrol','Dealer','Manual'],dtype=object).reshape(1,6)

# %%
vlu.predict(tst_inp)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# array([571961.83397911])
